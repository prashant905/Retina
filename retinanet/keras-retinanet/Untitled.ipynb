# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
im = '/notebooks/cropped/044/peakpoint/052.bmp' 
im =cv2.imread(im)
cv2.rectangle(im,(28,40),(53,91),(0,255,0),2)
# cv2.rectangle(im,(29,131),(41,150),(0,255,0),2)
# cv2.rectangle(im,(4,134),(16,163),(0,255,0),2)
plt.imshow(im)

# %%
import pandas as pd
import numpy as np

# %%
csv = '/notebooks/044.csv'
csv =pd.read_csv(csv,header=None)
for index, row in csv.iterrows():
    row3 = csv.iloc[index][3] + csv.iloc[index][1] 
    csv[3][index] =int(row3)
    row4 = csv.iloc[index][4] + csv.iloc[index][2]
    csv[4][index] =int(row4)
csv = csv.convert_objects(convert_numeric=True)
csv['peakpoint']='peakpoint'
print csv
csv.to_csv('044.csv',header=None,index=None)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#                                  0   1   2    3    4  peakpoint
# 0    cropped/044/peakpoint/040.bmp  82  99  102  137  peakpoint
# 1    cropped/044/peakpoint/041.bmp  85  96  100  139  peakpoint
# 2    cropped/044/peakpoint/042.bmp  83  63  103  133  peakpoint
# 3    cropped/044/peakpoint/043.bmp  83  83  101  135  peakpoint
# 4    cropped/044/peakpoint/044.bmp  76  70   97  113  peakpoint
# ...

# %%
#add column peakopoint to csv
csv = '/notebooks/peak.csv'
csv =pd.read_csv(csv,header=None)
csv = csv.convert_objects(convert_numeric=True)
csv['peakpoint']='peakpoint'
csv.to_csv('newpeak.csv',header=None,index=None)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   after removing the cwd from sys.path.

# %%
csv = '/notebooks/test_complete.csv'
csv =pd.read_csv(csv,header=None)
# csv['label'] = 'peakpoint'
csv
for index, row in csv.iterrows():
    row3 = csv.iloc[index][3] + csv.iloc[index][1] 
    csv[3][index] =int(row3)
    row4 = csv.iloc[index][4] + csv.iloc[index][2]
    csv[4][index] =int(row4)
# print csv
csv.to_csv('test_complete1.csv',header=None,index=None)

# %%
csv = '/notebooks/keras-retinanet/4036.csv'
csv =pd.read_csv(csv,header=None)
for index, row in csv.iterrows():
    row1 = int(csv.iloc[index][1])
    csv.iloc[index][1] =row1
    row2 = int(csv.iloc[index][2])
    csv.iloc[index][2] =row2
    row3= int(csv.iloc[index][3])
    csv.iloc[index][3] =row3
    row4 = int(csv.iloc[index][4])
    csv.iloc[index][4] =row4
print csv
csv.to_csv('4036.csv',header=None,index=None)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# ...
